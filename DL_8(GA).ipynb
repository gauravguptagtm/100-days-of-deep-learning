# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravguptagtm/deep-learning-notebook/blob/main/DL_8(GA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['Serial No.'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train , y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 304        313          106                  2  2.5   2.0  8.43         0
# 243        325          114                  3  3.5   3.0  9.04         1
# 43         332          117                  4  4.5   4.0  9.10         0
# 251        316           99                  2  2.5   3.0  9.00         0
# 388        296           97                  2  1.5   2.0  7.80         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 368        298           92                  1  2.0   2.0  7.88         0
# 214        331          117                  4  4.5   5.0  9.42         1
# 268        327          113                  4  4.5   5.0  9.14         0
# 234        330          113                  5  5.0   4.0  9.31         1
# 361        334          116                  4  4.0   3.5  9.54         1
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(7, activation='relu', input_dim=7))
model.add(Dense(7, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 7)                 56
#
#  dense_4 (Dense)             (None, 1)                 8
#
# ...
# Total params: 120 (480.00 Byte)
# Trainable params: 120 (480.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='Adam')

# %%
model.fit(X_train_scaled, y_train, epochs=10)
# Out:
# Epoch 1/10
# 13/13 [==============================] - 1s 3ms/step - loss: 0.7780
# Epoch 2/10
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4906
# Epoch 3/10
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2646
# Epoch 4/10
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1095
# Epoch 5/10
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 6/10
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0353
# Epoch 7/10
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0333
# Epoch 8/10
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0312
# Epoch 9/10
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0297
# Epoch 10/10
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0287

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -0.8961041603097837
