# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravguptagtm/deep-learning-notebook/blob/main/DL_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MLP Notation
#
# - trainable parameter = total # of weight + biases parameter
# - Output of a layer is input to next layer.
#   ![Screenshot from 2024-03-10 09-12-47.png](data:image/png;base64,...)

# %% [markdown]
# # MLP
#
# A Multi-Layer Perceptron (MLP) is a type of artificial neural network characterized by its multiple layers of nodes (neurons). It consists of an input layer, one or more hidden layers, and an output layer. Each connection between nodes is associated with a weight, and each node applies an activation function to the weighted sum of its inputs. MLPs are trained using algorithms like backpropagation to learn and make predictions.

# %% [markdown]
# # Intution of MLP
#
# - Suppose We take two perceptron.
# - These two generate two lines.
# - We superimpose one over other.
# - Now apply smoothening.
#
# # In Math terms:
#
# - We just find out probabilty on both perceptron.
# - Now combine the probability and apply sigmoid function.
#
#
# Now let's we want that impact of one perceptron is more than other.
# For this we can use weighted addition and we use a bias in output side.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Forward Propogation
#
# ![image.png](data:image/png;base64,...)
